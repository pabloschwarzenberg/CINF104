# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sb
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
data=pd.read_csv("dataset.csv",sep=";")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 54 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   estado  467 non-null    object
#  1   e0      467 non-null    int64
#  2   e1      467 non-null    int64
#  3   e2      467 non-null    int64
#  4   e3      467 non-null    int64
#  5   e4      467 non-null    int64
#  6   e5      467 non-null    int64
#  7   e6      467 non-null    int64
#  8   e7      467 non-null    int64
#  9   e8      467 non-null    int64
#  10  e9      467 non-null    int64
#  11  e10     467 non-null    int64
#  12  e11     467 non-null    int64
#  13  e12     467 non-null    int64
#  14  e13     467 non-null    int64
#  15  e14     467 non-null    int64
#  16  e15     467 non-null    int64
#  17  e16     467 non-null    int64
#  18  e17     467 non-null    int64
#  19  e18     467 non-null    int64
#  20  e19     467 non-null    int64
#  21  e20     467 non-null    int64
#  22  e21     467 non-null    int64
#  23  e22     467 non-null    int64
#  24  e23     467 non-null    int64
#  25  e24     467 non-null    int64
#  26  e25     467 non-null    int64
#  27  e26     467 non-null    int64
#  28  e27     467 non-null    int64
#  29  e28     467 non-null    int64
#  30  e29     467 non-null    int64
#  31  e30     467 non-null    int64
#  32  e31     467 non-null    int64
#  33  e32     467 non-null    int64
#  34  e33     467 non-null    int64
#  35  e34     467 non-null    int64
#  36  e35     467 non-null    int64
#  37  e36     467 non-null    int64
#  38  e37     467 non-null    int64
#  39  e38     467 non-null    int64
#  40  e39     467 non-null    int64
#  41  e40     467 non-null    int64
#  42  e41     467 non-null    int64
#  43  e42     467 non-null    int64
#  44  e43     467 non-null    int64
#  45  e44     467 non-null    int64
#  46  e45     467 non-null    int64
#  47  e46     467 non-null    int64
#  48  e47     467 non-null    int64
#  49  e48     467 non-null    int64
#  50  e49     467 non-null    int64
#  51  e50     467 non-null    int64
#  52  e51     467 non-null    int64
#  53  e52     467 non-null    int64
# dtypes: int64(53), object(1)
# memory usage: 197.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 54 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   estado  467 non-null    object
#  1   e0      467 non-null    object
#  2   e1      467 non-null    object
#  3   e2      467 non-null    object
#  4   e3      467 non-null    object
#  5   e4      467 non-null    object
#  6   e5      467 non-null    object
#  7   e6      467 non-null    object
#  8   e7      467 non-null    object
#  9   e8      467 non-null    object
#  10  e9      467 non-null    object
#  11  e10     467 non-null    object
#  12  e11     467 non-null    object
#  13  e12     467 non-null    object
#  14  e13     467 non-null    object
#  15  e14     467 non-null    object
#  16  e15     467 non-null    object
#  17  e16     467 non-null    object
#  18  e17     467 non-null    object
#  19  e18     467 non-null    object
#  20  e19     467 non-null    object
#  21  e20     467 non-null    object
#  22  e21     467 non-null    object
#  23  e22     467 non-null    object
#  24  e23     467 non-null    object
#  25  e24     467 non-null    object
#  26  e25     467 non-null    object
#  27  e26     467 non-null    object
#  28  e27     467 non-null    object
#  29  e28     467 non-null    object
#  30  e29     467 non-null    object
#  31  e30     467 non-null    object
#  32  e31     467 non-null    object
#  33  e32     467 non-null    object
#  34  e33     467 non-null    object
#  35  e34     467 non-null    object
#  36  e35     467 non-null    object
#  37  e36     467 non-null    object
#  38  e37     467 non-null    object
#  39  e38     467 non-null    object
#  40  e39     467 non-null    object
#  41  e40     467 non-null    object
#  42  e41     467 non-null    object
#  43  e42     467 non-null    object
#  44  e43     467 non-null    object
#  45  e44     467 non-null    object
#  46  e45     467 non-null    object
#  47  e46     467 non-null    object
#  48  e47     467 non-null    object
#  49  e48     467 non-null    object
#  50  e49     467 non-null    object
#  51  e50     467 non-null    object
#  52  e51     467 non-null    object
#  53  e52     467 non-null    object
# dtypes: object(54)
# memory usage: 197.1+ KB

# %%
y=pd.Categorical(data["estado"])
data["Y"]=y.codes

# %%
data["Y"].describe()
# Out:
# count    467.000000
# mean       0.104925
# std        0.306785
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: Y, dtype: float64

# %%
data["Y"].astype("object").describe()
# Out:
# count     467
# unique      2
# top         0
# freq      418
# Name: Y, dtype: int64

# %%
data["Y"].hist()
# Out:
# <Axes: >

# %%
data.groupby("estado").agg("sum").T
# Out:
# estado    A   R
# e0      335  10
# e1      267   3
# e2       16   1
# e3      339   7
# e4      383  22
# e5        0   0
# e6      268   6
# e7       79   1
# e8       21   0
# e9       40   1
# e10     342  10
# e11      37   0
# e12      66   0
# e13     119   3
# e14       0   0
# e15       0   0
# e16       0   0
# e17     382  23
# e18     252   5
# e19       0   0
# e20       0   0
# e21      35   0
# e22     355  12
# e23     318   6
# e24       0   0
# e25     380  25
# e26     368  17
# e27       0   0
# e28     162   3
# e29     348  16
# e30       0   0
# e31       4   0
# e32     259   6
# e33      10   1
# e34       0   0
# e35     223   4
# e36       0   0
# e37     179   3
# e38      83   1
# e39       0   0
# e40       0   0
# e41       0   0
# e42     313   3
# e43       0   0
# e44     304   7
# e45       0   0
# e46       0   0
# e47       0   0
# e48       4   0
# e49       0   0
# e50       0   0
# e51       0   0
# e52       0   0
# Y         0  49

# %%
yv_pred=np.loadtxt("stratified_yv_pred.csv",delimiter=";",skiprows=1)
yv=np.loadtxt("stratified_yv.csv",delimiter=";",skiprows=1)
yv=np.argmax(yv,axis=1)
yv_pred=np.argmax(yv_pred,axis=1)
matriz = confusion_matrix(yv, yv_pred)
print('Matriz de Confusión:')
print(matriz)
ax= plt.subplot()
sb.heatmap(matriz, annot=True, ax = ax, cmap="Oranges",fmt="d");
ax.set_xlabel('Valores predichos');ax.set_ylabel('valores verdaderos'); 
ax.set_title('Matriz de confusion');
# Out:
# Matriz de Confusión:
# [[38  0]
#  [ 4  0]]

# %%
yv_pred=np.loadtxt("undersampling_yv_pred.csv",delimiter=";",skiprows=1)
yv=np.loadtxt("undersampling_yv.csv",delimiter=";",skiprows=1)
yv=np.argmax(yv,axis=1)
yv_pred=np.argmax(yv_pred,axis=1)
matriz = confusion_matrix(yv, yv_pred)
print('Matriz de Confusión:')
print(matriz)
ax= plt.subplot()
sb.heatmap(matriz, annot=True, ax = ax, cmap="Oranges",fmt="d");
ax.set_xlabel('Valores predichos');ax.set_ylabel('valores verdaderos'); 
ax.set_title('Matriz de confusion');
# Out:
# Matriz de Confusión:
# [[5 0]
#  [0 4]]

# %%
yv_pred=np.loadtxt("oversampling_yv_pred.csv",delimiter=";",skiprows=1)
yv=np.loadtxt("oversampling_yv.csv",delimiter=";",skiprows=1)
yv=np.argmax(yv,axis=1)
yv_pred=np.argmax(yv_pred,axis=1)
matriz = confusion_matrix(yv, yv_pred)
print('Matriz de Confusión:')
print(matriz)
ax= plt.subplot()
sb.heatmap(matriz, annot=True, ax = ax, cmap="Oranges",fmt="d");
ax.set_xlabel('Valores predichos');ax.set_ylabel('valores verdaderos'); 
ax.set_title('Matriz de confusion');
# Out:
# Matriz de Confusión:
# [[34  4]
#  [ 8 30]]
